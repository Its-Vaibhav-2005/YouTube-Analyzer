# %% [markdown]
# # Parsing (Cleaning)

# %%
import pandas as pd
import json

# %%
INPUT = './data/history.json'
OUTPUT = './data/cleanHistory.csv'

# %%
with open(INPUT, 'r', encoding='utf-8') as f:
    data = json.load(f)
len(data)
# Out:
# 7600

# %%
parsedData = []

# %%
for history in data:
    if 'titleUrl' not in history:
        continue
    row = {
        'title': (history.get('title', 'Unknown')).replace('Watched ', "", 1),
        'date': history.get('time'),
        'video_url': history.get('titleUrl'),
        'channel': 'Unknown',
    }

    if 'subtitles' in history and isinstance(history['subtitles'], list):
        if len(history['subtitles'])>0:
            row['channel'] = history['subtitles'][0].get("name", 'Unknown')
    parsedData.append(row)

len(parsedData)
# Out:
# 7599

# %%
df = pd.DataFrame(parsedData)
df.head(10)
# Out:
#                                                title  \
# 0  Ara Ke Othlali Mein - Slowed And Reverb | Pawa...
# 1  Sajde - (16D Audio "Not 8D") | Faheem Abdullah...
# 2  Saiyaara Title Song (16D Audio "Not 8D") | Tan...
# 3  Barbaad (16D Audio "Not 8D") | Saiyaara | Ahaa...
# 4  GURU RANDHAWA - DOPAMINE (16D Audio "Not 8D") ...
# 5  Lutt Le Gaya (16D Audio "Not 8D") Dhurandhar |...
# 6  TWITTER SENTIMENT ANALYSIS (NLP) | Machine Lea...
# 7  Unstructured Data, Natural Language Processing...
# 8                      Introduction to R (Continued)
# 9  Low-Level Design Interview: Design Amazon Lock...
#
#                        date                                    video_url  \
# 0  2026-01-29T17:22:46.857Z  https://www.youtube.com/watch?v=MHQ7YSO28ZY
# 1  2026-01-29T17:20:19.647Z  https://www.youtube.com/watch?v=NY4PJAuqCMY
# 2  2026-01-29T17:14:05.588Z  https://www.youtube.com/watch?v=nNcrLdmuTg8
# 3  2026-01-29T17:08:03.933Z  https://www.youtube.com/watch?v=OK2cQg7xbQc
# 4  2026-01-29T17:05:23.447Z  https://www.youtube.com/watch?v=TRfQMVuMzHs
# 5  2026-01-29T17:01:11.335Z  https://www.youtube.com/watch?v=Rp6DOypeBtk
# 6  2026-01-29T16:43:44.061Z  https://www.youtube.com/watch?v=4YGkfAd2iXM
# 7  2026-01-29T15:39:34.332Z  https://www.youtube.com/watch?v=fxAvc_1md44
# 8  2026-01-29T14:28:06.918Z  https://www.youtube.com/watch?v=Rftn5XkYAhk
# 9  2026-01-29T14:09:23.342Z  https://www.youtube.com/watch?v=s6nGkoGJhXk
#
#                                        channel
# 0                                    Lofi Roxx
# 1                                 ROYAL JAAT ♪
# 2                                 ROYAL JAAT ♪
# 3                                 ROYAL JAAT ♪
# 4                                 ROYAL JAAT ♪
# 5                                 ROYAL JAAT ♪
# 6                                GeeksforGeeks
# 7                            Dr. Ahmad Bukhari
# 8                               NPTEL-NOC IITM
# 9  Hello Interview - SWE Interview Preparation

# %%
df['date'] = pd.to_datetime(df['date'], format="mixed")
df.head(10)
# Out:
#                                                title  \
# 0  Ara Ke Othlali Mein - Slowed And Reverb | Pawa...
# 1  Sajde - (16D Audio "Not 8D") | Faheem Abdullah...
# 2  Saiyaara Title Song (16D Audio "Not 8D") | Tan...
# 3  Barbaad (16D Audio "Not 8D") | Saiyaara | Ahaa...
# 4  GURU RANDHAWA - DOPAMINE (16D Audio "Not 8D") ...
# 5  Lutt Le Gaya (16D Audio "Not 8D") Dhurandhar |...
# 6  TWITTER SENTIMENT ANALYSIS (NLP) | Machine Lea...
# 7  Unstructured Data, Natural Language Processing...
# 8                      Introduction to R (Continued)
# 9  Low-Level Design Interview: Design Amazon Lock...
#
#                               date  \
# 0 2026-01-29 17:22:46.857000+00:00
# 1 2026-01-29 17:20:19.647000+00:00
# 2 2026-01-29 17:14:05.588000+00:00
# 3 2026-01-29 17:08:03.933000+00:00
# 4 2026-01-29 17:05:23.447000+00:00
# 5 2026-01-29 17:01:11.335000+00:00
# 6 2026-01-29 16:43:44.061000+00:00
# 7 2026-01-29 15:39:34.332000+00:00
# 8 2026-01-29 14:28:06.918000+00:00
# 9 2026-01-29 14:09:23.342000+00:00
#
#                                      video_url  \
# 0  https://www.youtube.com/watch?v=MHQ7YSO28ZY
# 1  https://www.youtube.com/watch?v=NY4PJAuqCMY
# 2  https://www.youtube.com/watch?v=nNcrLdmuTg8
# 3  https://www.youtube.com/watch?v=OK2cQg7xbQc
# 4  https://www.youtube.com/watch?v=TRfQMVuMzHs
# 5  https://www.youtube.com/watch?v=Rp6DOypeBtk
# 6  https://www.youtube.com/watch?v=4YGkfAd2iXM
# 7  https://www.youtube.com/watch?v=fxAvc_1md44
# 8  https://www.youtube.com/watch?v=Rftn5XkYAhk
# 9  https://www.youtube.com/watch?v=s6nGkoGJhXk
#
#                                        channel
# 0                                    Lofi Roxx
# 1                                 ROYAL JAAT ♪
# 2                                 ROYAL JAAT ♪
# 3                                 ROYAL JAAT ♪
# 4                                 ROYAL JAAT ♪
# 5                                 ROYAL JAAT ♪
# 6                                GeeksforGeeks
# 7                            Dr. Ahmad Bukhari
# 8                               NPTEL-NOC IITM
# 9  Hello Interview - SWE Interview Preparation

# %%
df.describe()
# Out:
#                   title                              date  \
# count              7599                              7599
# unique             6093                               NaN
# top     California Love                               NaN
# freq                 22                               NaN
# mean                NaN  2025-08-04 22:36:15.977662+00:00
# min                 NaN  2025-02-01 17:08:23.913000+00:00
# 25%                 NaN  2025-04-29 17:25:40.273000+00:00
# 50%                 NaN  2025-07-19 17:18:26.651000+00:00
# 75%                 NaN  2025-12-05 10:55:36.368500+00:00
# max                 NaN  2026-01-29 17:22:46.857000+00:00
#
#                                             video_url  channel
# count                                            7599     7599
# unique                                           6205     3486
# top     https://music.youtube.com/watch?v=eD8lmkBCma4  Unknown
# freq                                               22      397
# mean                                              NaN      NaN
# min                                               NaN      NaN
# 25%                                               NaN      NaN
# 50%                                               NaN      NaN
# 75%                                               NaN      NaN
# max                                               NaN      NaN

# %%
df = df[df['title']!='Unknown']

# %%
f"Total videos watched: {len(df)}"
# Out:
# 'Total videos watched: 7599'

# %%
f"Date Range: {df['date'].min()} to {df['date'].max()}"
# Out:
# 'Date Range: 2025-02-01 17:08:23.913000+00:00 to 2026-01-29 17:22:46.857000+00:00'

# %%
f"Unique channels: {df['channel'].nunique()}"
# Out:
# 'Unique channels: 3486'

# %%
df.to_csv(OUTPUT, index=False)
